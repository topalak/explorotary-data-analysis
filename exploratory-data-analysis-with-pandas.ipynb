# %%
import pandas as pd
pd.set_option('display.max_columns', None) #.head does not show all the columns that data frame has. It shows first 5 and last 5 rows. it is shows every single column in df while using .head()
#pd.set_option('max_columns', 200)
import numpy as np

# %%
df = pd.read_csv('../input/rollercoaster-database/coaster_db.csv')

# %% [markdown]
# # GENERAL UNDERSTANDING

# %%
df.shape

# %%
df.sample( )
#gives you a random sample in df

# %%
df.head(5)

# %%
df.iloc[:10].transpose()
#I prefer df.iloc[].transpose() instead of df.head()  because iloc is shows the data more readable.

# %%
df.describe()
#df.describe() it shows us some statistics like mean, std, quarters

# %% [markdown]
# # DATA PREPERATION (dropping columns or some rows)

# %% [markdown]
# **There are 2 ways to create a subset of the main df
# First one is getting all the column names and making comment lines for the columns that we dont want to see**

# %% [markdown]
# **here's the first way**

# %%
'''df.drop(['Opening date'], axis=1) #axis=0 for drop row axis=1 for drop column'''

# %%
df.columns

# %%
df = df[['coaster_name',
 #   'Length', 'Speed',
    'Location', 'Status', 
    #'Opening date',
  #     'Type',
    'Manufacturer',
  #  'Height restriction', 'Model', 'Height',
      # 'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
      # 'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
      # 'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
      # 'Track layout', 'Fastrack available', 'Soft opening date.1',
      # 'Closing date', 'Opened', 'Replaced by', 'Website',
      # 'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
      # 'Single rider line available', 'Restraint Style',
      # 'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced','latitude', 'longitude', 'Type_Main',
       'opening_date_clean',
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph',
    #'height_value', 'height_unit', 'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

''' copy() is for saving the main df'''

# %% [markdown]
# **important thing is rows must finished with comma**

# %%
df.dtypes #we see openning_data_clean is object but it is datetime format we need to convert that

# %%
df['opening_date_clean'] = pd.to_datetime (df['opening_date_clean'])

# %%
df.dtypes

# %%
df.rename(columns = {'opening_date_clean' : 'Opening_date_clean'})
